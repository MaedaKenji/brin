# %%
# !pip install selenium webdriver-manager
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------- -------------------------- 3.1/9.5 MB 18.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 21.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 19.8 MB/s  0:00:00
# ...
#
#    -- -------------------------------------  1/14 [websocket-client]
#   Attempting uninstall: urllib3
#    -- -------------------------------------  1/14 [websocket-client]
#     Found existing installation: urllib3 2.6.1
#    -- -------------------------------------  1/14 [websocket-client]
#     Uninstalling urllib3-2.6.1:
#    -- -------------------------------------  1/14 [websocket-client]
#       Successfully uninstalled urllib3-2.6.1
#    -- -------------------------------------  1/14 [websocket-client]
#    ----- ----------------------------------  2/14 [urllib3]
#    ----------- ----------------------------  4/14 [python-dotenv]
# ...
